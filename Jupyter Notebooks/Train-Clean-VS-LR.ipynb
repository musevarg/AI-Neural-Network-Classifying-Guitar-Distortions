# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import normalize, to_categorical
from keras.preprocessing import image
from keras.models import model_from_json
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from prettytable import PrettyTable

# %%
rootPath = './spectrograms2/All/'
imgPath = 'train/clean/'
testImgPath = rootPath + imgPath + os.listdir(rootPath + imgPath)[0]
res = [cv2.imread(testImgPath).shape[0], cv2.imread(testImgPath).shape[1]]

print('Current Resolution: \t' + str(res))

#res = [int(res[0]/2), int(res[1]/2)]
#print('New Resolution: \t' + str(res))

#res = [int(res[0]/1.5), int(res[1]/1.5)]
#print('New Resolution: \t' + str(res))

res = [int(res[0]/4), int(res[1]/4)]
print('New Resolution: \t' + str(res))
# Out:
# Current Resolution: 	[540, 1080]
# New Resolution: 	[135, 270]

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory(
    rootPath + 'train/',
    target_size = (res[0], res[1]),
    batch_size = 10,
    class_mode = 'binary'
)

validation_dataset = validation.flow_from_directory(
    rootPath + 'validate/',
    target_size = (res[0], res[1]),
    batch_size = 10,
    class_mode = 'binary'
)
# Out:
# Found 240 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
#print(train_dataset.class_indices)
#print(validation_dataset.class_indices)

# %% [markdown]
# # train generator (rotate images)
#
# train_datagen = ImageDataGenerator(rotation_range=45,
#     width_shift_range=0.2,
#     zoom_range = 0.2,
#     horizontal_flip = True)
# train_datagen.fit(train_dataset)
#
# train_generator = train_datagen.flow(
#     train_dataset,
#     batch_size = 32)

# %%
# old model
activation = 'relu'
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation=activation, input_shape=(res[0], res[1], 3)),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(32,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    ##
    tf.keras.layers.Flatten(),
    ##
    tf.keras.layers.Dense(512, activation=activation),
    ##
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

# %% [markdown]
# activation = 'sigmoid'
# model = Sequential()
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', input_shape = (res[0], res[1], 3)))
# model.add(BatchNormalization())
#
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Flatten())
# model.add(Dense(128, activation = activation, kernel_initializer = 'he_uniform'))
# model.add(Dense(1, activation = 'softmax'))
#
# model.compile(optimizer = 'rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
# print(model.summary())

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(lr=0.001),
    metrics=['accuracy']
)

# %%
model_fit = model.fit(
    train_dataset,
    steps_per_epoch=24,
    epochs=100,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 8s 311ms/step - loss: 1.0051 - accuracy: 0.5920 - val_loss: 0.3595 - val_accuracy: 0.8667
# Epoch 2/50
# 24/24 [==============================] - 8s 310ms/step - loss: 0.3268 - accuracy: 0.8739 - val_loss: 0.2138 - val_accuracy: 0.9333
# Epoch 3/50
# 24/24 [==============================] - 7s 301ms/step - loss: 0.1403 - accuracy: 0.9624 - val_loss: 0.3066 - val_accuracy: 0.9000
# Epoch 4/50
# 24/24 [==============================] - 7s 292ms/step - loss: 0.3322 - accuracy: 0.8859 - val_loss: 0.2366 - val_accuracy: 0.9000
# Epoch 5/50
# 24/24 [==============================] - 7s 305ms/step - loss: 0.1242 - accuracy: 0.9621 - val_loss: 0.3707 - val_accuracy: 0.9333
# Epoch 6/50
# 24/24 [==============================] - 7s 291ms/step - loss: 0.0941 - accuracy: 0.9725 - val_loss: 0.2872 - val_accuracy: 0.9500
# Epoch 7/50
# 24/24 [==============================] - 7s 289ms/step - loss: 0.0495 - accuracy: 0.9831 - val_loss: 0.3241 - val_accuracy: 0.9500
# Epoch 8/50
# 24/24 [==============================] - 7s 272ms/step - loss: 0.0691 - accuracy: 0.9832 - val_loss: 0.3192 - val_accuracy: 0.9500
# Epoch 9/50
# 24/24 [==============================] - 7s 271ms/step - loss: 0.0226 - accuracy: 0.9898 - val_loss: 0.4561 - val_accuracy: 0.9500
# Epoch 10/50
# 24/24 [==============================] - 7s 280ms/step - loss: 0.0090 - accuracy: 0.9945 - val_loss: 0.3491 - val_accuracy: 0.9500
# Epoch 11/50
# 24/24 [==============================] - 7s 272ms/step - loss: 0.0184 - accuracy: 0.9978 - val_loss: 0.5132 - val_accuracy: 0.9500
# Epoch 12/50
# 24/24 [==============================] - 7s 279ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.6587 - val_accuracy: 0.9000
# Epoch 13/50
# 24/24 [==============================] - 7s 276ms/step - loss: 0.0072 - accuracy: 0.9921 - val_loss: 0.7587 - val_accuracy: 0.9333
# Epoch 14/50
# 24/24 [==============================] - 7s 279ms/step - loss: 3.1405e-04 - accuracy: 1.0000 - val_loss: 0.8302 - val_accuracy: 0.9333
# Epoch 15/50
# 24/24 [==============================] - 7s 278ms/step - loss: 0.0152 - accuracy: 0.9965 - val_loss: 0.6656 - val_accuracy: 0.9333
# Epoch 16/50
# 24/24 [==============================] - 7s 306ms/step - loss: 2.8367e-04 - accuracy: 1.0000 - val_loss: 0.9166 - val_accuracy: 0.9333
# Epoch 17/50
# 24/24 [==============================] - 7s 306ms/step - loss: 0.0138 - accuracy: 0.9988 - val_loss: 0.6597 - val_accuracy: 0.9333
# Epoch 18/50
# 24/24 [==============================] - 7s 289ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.7372 - val_accuracy: 0.9333
# Epoch 19/50
# 24/24 [==============================] - 7s 287ms/step - loss: 8.7465e-04 - accuracy: 1.0000 - val_loss: 0.8393 - val_accuracy: 0.9333
# Epoch 20/50
# 24/24 [==============================] - 7s 281ms/step - loss: 1.3559e-04 - accuracy: 1.0000 - val_loss: 1.0869 - val_accuracy: 0.9333
# Epoch 21/50
# 24/24 [==============================] - 8s 312ms/step - loss: 1.3925e-04 - accuracy: 1.0000 - val_loss: 1.1212 - val_accuracy: 0.9333
# Epoch 22/50
# 24/24 [==============================] - 7s 299ms/step - loss: 0.0962 - accuracy: 0.9905 - val_loss: 0.9163 - val_accuracy: 0.9500
# Epoch 23/50
# 24/24 [==============================] - 7s 293ms/step - loss: 4.6061e-04 - accuracy: 1.0000 - val_loss: 1.0500 - val_accuracy: 0.9333
# Epoch 24/50
# 24/24 [==============================] - 7s 297ms/step - loss: 7.3851e-05 - accuracy: 1.0000 - val_loss: 1.2621 - val_accuracy: 0.9333
# Epoch 25/50
# 24/24 [==============================] - 7s 306ms/step - loss: 2.4184e-06 - accuracy: 1.0000 - val_loss: 1.3404 - val_accuracy: 0.9333
# Epoch 26/50
# 24/24 [==============================] - 8s 336ms/step - loss: 7.9979e-07 - accuracy: 1.0000 - val_loss: 1.4215 - val_accuracy: 0.9333
# Epoch 27/50
# 24/24 [==============================] - 8s 328ms/step - loss: 1.7654e-07 - accuracy: 1.0000 - val_loss: 1.4533 - val_accuracy: 0.9333
# Epoch 28/50
# 24/24 [==============================] - 8s 334ms/step - loss: 9.4266e-07 - accuracy: 1.0000 - val_loss: 2.0850 - val_accuracy: 0.9167
# Epoch 29/50
# 24/24 [==============================] - 7s 310ms/step - loss: 0.0522 - accuracy: 0.9902 - val_loss: 1.7507 - val_accuracy: 0.9333
# Epoch 30/50
# 24/24 [==============================] - 8s 314ms/step - loss: 3.4712e-05 - accuracy: 1.0000 - val_loss: 2.1943 - val_accuracy: 0.9333
# Epoch 31/50
# 24/24 [==============================] - 7s 302ms/step - loss: 4.5538e-08 - accuracy: 1.0000 - val_loss: 2.2253 - val_accuracy: 0.9333
# Epoch 32/50
# 24/24 [==============================] - 7s 307ms/step - loss: 6.7365e-08 - accuracy: 1.0000 - val_loss: 2.2527 - val_accuracy: 0.9333
# Epoch 33/50
# 24/24 [==============================] - 9s 370ms/step - loss: 1.4296e-08 - accuracy: 1.0000 - val_loss: 2.4490 - val_accuracy: 0.9333
# Epoch 34/50
# 24/24 [==============================] - 10s 409ms/step - loss: 6.2803e-08 - accuracy: 1.0000 - val_loss: 2.6037 - val_accuracy: 0.9333
# Epoch 35/50
# 24/24 [==============================] - 8s 312ms/step - loss: 2.4836e-08 - accuracy: 1.0000 - val_loss: 2.5441 - val_accuracy: 0.9333
# Epoch 36/50
# 24/24 [==============================] - 9s 366ms/step - loss: 1.6435e-09 - accuracy: 1.0000 - val_loss: 2.6119 - val_accuracy: 0.9333
# Epoch 37/50
# 24/24 [==============================] - 9s 390ms/step - loss: 1.2192e-09 - accuracy: 1.0000 - val_loss: 2.6705 - val_accuracy: 0.9333
# Epoch 38/50
# 24/24 [==============================] - 7s 298ms/step - loss: 6.5541e-10 - accuracy: 1.0000 - val_loss: 2.6746 - val_accuracy: 0.9333
# Epoch 39/50
# 24/24 [==============================] - 8s 325ms/step - loss: 1.6821e-09 - accuracy: 1.0000 - val_loss: 2.8072 - val_accuracy: 0.9333
# Epoch 40/50
# 24/24 [==============================] - 8s 335ms/step - loss: 8.4335e-10 - accuracy: 1.0000 - val_loss: 3.2223 - val_accuracy: 0.9167
# Epoch 41/50
# 24/24 [==============================] - 9s 374ms/step - loss: 0.0502 - accuracy: 0.9989 - val_loss: 0.9722 - val_accuracy: 0.9333
# Epoch 42/50
# 24/24 [==============================] - 7s 306ms/step - loss: 0.5264 - accuracy: 0.9284 - val_loss: 1.0777 - val_accuracy: 0.9500
# Epoch 43/50
# 24/24 [==============================] - 7s 309ms/step - loss: 5.0434e-05 - accuracy: 1.0000 - val_loss: 1.1429 - val_accuracy: 0.9500
# Epoch 44/50
# 24/24 [==============================] - 8s 321ms/step - loss: 2.0990e-05 - accuracy: 1.0000 - val_loss: 1.2262 - val_accuracy: 0.9500
# Epoch 45/50
# 24/24 [==============================] - 7s 308ms/step - loss: 1.0640e-05 - accuracy: 1.0000 - val_loss: 1.2900 - val_accuracy: 0.9333
# Epoch 46/50
# 24/24 [==============================] - 8s 321ms/step - loss: 3.5494e-06 - accuracy: 1.0000 - val_loss: 1.5343 - val_accuracy: 0.9333
# Epoch 47/50
# 24/24 [==============================] - 7s 296ms/step - loss: 0.0816 - accuracy: 0.9924 - val_loss: 1.0644 - val_accuracy: 0.9333
# Epoch 48/50
# 24/24 [==============================] - 7s 306ms/step - loss: 2.4093e-05 - accuracy: 1.0000 - val_loss: 1.2778 - val_accuracy: 0.9333
# Epoch 49/50
# 24/24 [==============================] - 7s 295ms/step - loss: 4.6216e-06 - accuracy: 1.0000 - val_loss: 1.3360 - val_accuracy: 0.9333
# Epoch 50/50
# 24/24 [==============================] - 7s 298ms/step - loss: 4.0068e-06 - accuracy: 1.0000 - val_loss: 1.4872 - val_accuracy: 0.9333

# %%
def resultStore(file, pred, results):
    pred = pred.lower() if pred != 'lead or rhythm' else 'lead' if 'lead' in file else 'rhythm'
    if pred in file:
        results[0] = 'PASS'
        results[1] = results[1] + 1
    else:
        results[0] = 'FAIL'
        results[2] = results[2] + 1
    return results

def resultStats(results):
    total = results[1] + results[2]
    p = round(results[1]*100/total, 2)
    f = round(results[2]*100/total, 2)
    return 'Pass: ' + str(p) + '% (' + str(results[1]) + '), Fail: ' + str(f) + '% (' + str(results[2]) + '), Total: ' + str(total)

# %%
validation_dataset.class_indices
classes = {v: k for k, v in validation_dataset.class_indices.items()}
print(classes)
# Out:
# {0: 'clean', 1: 'lead or rhythm'}

# %% [markdown]
# testPath = rootPath + 'test/'
# results = ["", 0, 0]
#
# table = PrettyTable()
# table.field_names = ["1", "File", "2", "Class", "3", "Prediction", "4", "Result", " "]
#
# for i in os.listdir(testPath):
#     img = image.load_img(
#         testPath + '//' + i,
#         target_size = (res[0], res[1])
#     )
#
#     X = image.img_to_array(img)
#     X = np.expand_dims(X, axis=0)
#     images = np.vstack([X])
#     prediction = int(model.predict(images))
#
#     results = resultStore(i, classes[prediction][3:-4], results)
#     splt = i.split('_session_')
#     clss = splt[0]
#     fname = splt[1].replace('_', ' ')
#     table.add_row(["", fname[:-4], "", clss, "", classes[prediction][3:-4], "", results[0], ""])
#
# table.align = 'l'
# print(table)
#
# print('\n' + resultStats(results))

# %%
def get_precision(prec, result):
    if result == "PASS":
        prec[0] = prec[0] + 1
        prec[1] = prec[1] + 1
    else:
        prec[1] = prec[1] + 1
    return prec

def get_recall(rec, result, clss):
    if clss == 0:
        if result == "PASS":
            rec[0] = rec[0] + 1
            rec[1] = rec[1] + 1
        else:
            rec[3] = rec[3] + 1
    else:
        if result == "PASS":
            rec[2] = rec[2] + 1
            rec[3] = rec[3] + 1
        else:
            rec[1] = rec[1] + 1
    return rec

def get_fscore(prec, rec):
    return 2 * ((prec * rec) / (prec + rec))

def get_metrics(precision1, precision2, recall, classes):
    precision = [round((precision1[0]/precision1[1]), 2)*100, round((precision2[0]/precision2[1]), 2)*100]
    recall = [round((recall[0]/recall[1]), 2)*100, round((recall[2]/recall[3]), 2)*100]
    fscore = [round(get_fscore(precision[0], recall[0]),2), round(get_fscore(precision[1], recall[1]),2)]

    metrics_table = PrettyTable()
    metrics_table.field_names = ["Class", "Precision", "Recall", "F-Score"]
    for i in classes:
        metrics_table.add_row([classes[i], precision[i], recall[i], fscore[i]])
    return metrics_table

# %%
recall = [0,0,0,0]
precision1 = [0,0]
precision2 = [0,0]
fscore = [0,0]

testPath = rootPath + 'test/'
results = ["", 0, 0]

table = PrettyTable()
table.field_names = ["File", "Class", "Prediction", "Result"]

for i in os.listdir(testPath):
    img = image.load_img(
        testPath + '//' + i,
        target_size = (res[0], res[1])
    )

    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    prediction = int(model.predict(images))
    
    results = resultStore(i, classes[prediction], results)
    splt = i.split('_session_')
    clss = splt[0]
    fname = splt[1].replace('_', ' ')
    table.add_row([fname[:-4] + "    ", clss + "    ", classes[prediction] + "    ", results[0] + "    "])

table.align = 'l'
print(table)

print('\n' + resultStats(results))

print(get_metrics(precision1, precision2, recall, classes))
# Out:
# +-----------------------------------+------------+--------------------+----------+
# | File                              | Class      | Prediction         | Result   |
# +-----------------------------------+------------+--------------------+----------+
# | Audio 51                          | clean      | clean              | PASS     |
# | Audio 52                          | clean      | clean              | PASS     |
# | Audio 54                          | clean      | clean              | PASS     |
# | Audio 55                          | clean      | clean              | PASS     |
# | Audio 56                          | clean      | clean              | PASS     |
# | Audio 57                          | clean      | clean              | PASS     |
# | Audio 58                          | clean      | clean              | PASS     |
# | Audio 59                          | clean      | clean              | PASS     |
# | Audio 60                          | clean      | clean              | PASS     |
# | Audio 53                          | clean      | clean              | PASS     |
# | Soundcloud 10                     | clean      | clean              | PASS     |
# | The Call Of Ktulu 2               | clean      | clean              | PASS     |
# | The Number Of The Beast 2         | clean      | clean              | PASS     |
# | The Pale King 2                   | clean      | clean              | PASS     |
# | The Call Of Ktulu                 | clean      | clean              | PASS     |
# | The Number Of The Beast           | clean      | clean              | PASS     |
# | The Pale King                     | clean      | clean              | PASS     |
# | You Shook Me All Night Long 2     | clean      | clean              | PASS     |
# | You Shook Me All Night Long 3     | clean      | clean              | PASS     |
# | You Shook Me All Night Long       | clean      | clean              | PASS     |
# | Audio 51                          | lead       | lead or rhythm     | PASS     |
# | Audio 52                          | lead       | lead or rhythm     | PASS     |
# | Audio 53                          | lead       | lead or rhythm     | PASS     |
# | Audio 54                          | lead       | lead or rhythm     | PASS     |
# | Audio 55                          | lead       | lead or rhythm     | PASS     |
# | Audio 56                          | lead       | lead or rhythm     | PASS     |
# | Audio 57                          | lead       | lead or rhythm     | PASS     |
# | Audio 58                          | lead       | lead or rhythm     | PASS     |
# | Audio 59                          | lead       | lead or rhythm     | PASS     |
# | Audio 60                          | lead       | lead or rhythm     | PASS     |
# | Soundcloud 10                     | lead       | lead or rhythm     | PASS     |
# | The Call Of Ktulu 2               | lead       | lead or rhythm     | PASS     |
# | The Number Of The Beast 2         | lead       | lead or rhythm     | PASS     |
# | The Pale King 2                   | lead       | lead or rhythm     | PASS     |
# | The Call Of Ktulu                 | lead       | lead or rhythm     | PASS     |
# | The Number Of The Beast           | lead       | lead or rhythm     | PASS     |
# | The Pale King                     | lead       | lead or rhythm     | PASS     |
# | You Shook Me All Night Long 2     | lead       | lead or rhythm     | PASS     |
# | You Shook Me All Night Long 3     | lead       | lead or rhythm     | PASS     |
# | You Shook Me All Night Long       | lead       | lead or rhythm     | PASS     |
# | Audio 51                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 52                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 53                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 54                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 55                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 56                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 57                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 58                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 59                          | rhythm     | lead or rhythm     | PASS     |
# | Audio 60                          | rhythm     | lead or rhythm     | PASS     |
# | Soundcloud 10                     | rhythm     | lead or rhythm     | PASS     |
# | The Call Of Ktulu 2               | rhythm     | lead or rhythm     | PASS     |
# | The Number Of The Beast 2         | rhythm     | lead or rhythm     | PASS     |
# | The Pale King 2                   | rhythm     | lead or rhythm     | PASS     |
# | The Call Of Ktulu                 | rhythm     | lead or rhythm     | PASS     |
# | The Number Of The Beast           | rhythm     | lead or rhythm     | PASS     |
# | The Pale King                     | rhythm     | lead or rhythm     | PASS     |
# | You Shook Me All Night Long 2     | rhythm     | lead or rhythm     | PASS     |
# | You Shook Me All Night Long 3     | rhythm     | lead or rhythm     | PASS     |
# | You Shook Me All Night Long       | rhythm     | lead or rhythm     | PASS     |
# +-----------------------------------+------------+--------------------+----------+
#
# Pass: 100.0% (60), Fail: 0.0% (0), Total: 60

# %%
#plot the training and validation accuracy and loss at each epoch
plt.subplot(1, 2, 1)
loss = model_fit.history['loss']
val_loss = model_fit.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'royalblue', label='Training loss')
plt.plot(epochs, val_loss, 'coral', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
acc = model_fit.history['accuracy']
val_acc = model_fit.history['val_accuracy']
plt.plot(epochs, acc, 'royalblue', label='Training acc')
plt.plot(epochs, val_acc, 'coral', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.rcParams['figure.figsize'] = [12, 5]
plt.tight_layout()
plt.savefig("test.pdf", format="pdf")
plt.show()

# %%
# Save trained model
json_model = model.to_json()

#save the model architecture to JSON file
with open('model-clean-lr-100p.json', 'w') as json_file:
    json_file.write(json_model)

model.save('model-clean-lr-100p.h5')

# %%
# Do a test with loaded model

loaded_model = load_model('model-clean-lr-100p.h5')

testPath = rootPath + 'test/'
results = ["", 0, 0]

table = PrettyTable()
table.field_names = ["File", "Class", "Prediction", "Result"]

for i in os.listdir(testPath):
    img = image.load_img(
        testPath + '//' + i,
        target_size = (res[0], res[1])
    )

    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    prediction = int(loaded_model.predict(images))
    
    results = resultStore(i, classes[prediction], results)
    splt = i.split('_session_')
    clss = splt[0]
    fname = splt[1].replace('_', ' ')
    table.add_row([fname[:-4] + "    ", clss + "    ", classes[prediction], results[0] + "    "])

table.align = 'l'
print(table)

print('\n' + resultStats(results))
# Out:
# +-----------------------------------+------------+----------------+----------+
# | File                              | Class      | Prediction     | Result   |
# +-----------------------------------+------------+----------------+----------+
# | Audio 51                          | clean      | clean          | PASS     |
# | Audio 52                          | clean      | clean          | PASS     |
# | Audio 54                          | clean      | clean          | PASS     |
# | Audio 55                          | clean      | clean          | PASS     |
# | Audio 56                          | clean      | clean          | PASS     |
# | Audio 57                          | clean      | clean          | PASS     |
# | Audio 58                          | clean      | clean          | PASS     |
# | Audio 59                          | clean      | clean          | PASS     |
# | Audio 60                          | clean      | clean          | PASS     |
# | Audio 53                          | clean      | clean          | PASS     |
# | Soundcloud 10                     | clean      | clean          | PASS     |
# | The Call Of Ktulu 2               | clean      | clean          | PASS     |
# | The Number Of The Beast 2         | clean      | clean          | PASS     |
# | The Pale King 2                   | clean      | clean          | PASS     |
# | The Call Of Ktulu                 | clean      | clean          | PASS     |
# | The Number Of The Beast           | clean      | clean          | PASS     |
# | The Pale King                     | clean      | clean          | PASS     |
# | You Shook Me All Night Long 2     | clean      | clean          | PASS     |
# | You Shook Me All Night Long 3     | clean      | clean          | PASS     |
# | You Shook Me All Night Long       | clean      | clean          | PASS     |
# | Audio 51                          | lead       | lead or rhythm | PASS     |
# | Audio 52                          | lead       | lead or rhythm | PASS     |
# | Audio 53                          | lead       | lead or rhythm | PASS     |
# | Audio 54                          | lead       | lead or rhythm | PASS     |
# | Audio 55                          | lead       | lead or rhythm | PASS     |
# | Audio 56                          | lead       | lead or rhythm | PASS     |
# | Audio 57                          | lead       | lead or rhythm | PASS     |
# | Audio 58                          | lead       | lead or rhythm | PASS     |
# | Audio 59                          | lead       | lead or rhythm | PASS     |
# | Audio 60                          | lead       | lead or rhythm | PASS     |
# | Soundcloud 10                     | lead       | lead or rhythm | PASS     |
# | The Call Of Ktulu 2               | lead       | lead or rhythm | PASS     |
# | The Number Of The Beast 2         | lead       | lead or rhythm | PASS     |
# | The Pale King 2                   | lead       | lead or rhythm | PASS     |
# | The Call Of Ktulu                 | lead       | lead or rhythm | PASS     |
# | The Number Of The Beast           | lead       | lead or rhythm | PASS     |
# | The Pale King                     | lead       | lead or rhythm | PASS     |
# | You Shook Me All Night Long 2     | lead       | lead or rhythm | PASS     |
# | You Shook Me All Night Long 3     | lead       | lead or rhythm | PASS     |
# | You Shook Me All Night Long       | lead       | lead or rhythm | PASS     |
# | Audio 51                          | rhythm     | lead or rhythm | PASS     |
# | Audio 52                          | rhythm     | lead or rhythm | PASS     |
# | Audio 53                          | rhythm     | lead or rhythm | PASS     |
# | Audio 54                          | rhythm     | lead or rhythm | PASS     |
# | Audio 55                          | rhythm     | lead or rhythm | PASS     |
# | Audio 56                          | rhythm     | lead or rhythm | PASS     |
# | Audio 57                          | rhythm     | lead or rhythm | PASS     |
# | Audio 58                          | rhythm     | lead or rhythm | PASS     |
# | Audio 59                          | rhythm     | lead or rhythm | PASS     |
# | Audio 60                          | rhythm     | lead or rhythm | PASS     |
# | Soundcloud 10                     | rhythm     | lead or rhythm | PASS     |
# | The Call Of Ktulu 2               | rhythm     | lead or rhythm | PASS     |
# | The Number Of The Beast 2         | rhythm     | lead or rhythm | PASS     |
# | The Pale King 2                   | rhythm     | lead or rhythm | PASS     |
# | The Call Of Ktulu                 | rhythm     | lead or rhythm | PASS     |
# | The Number Of The Beast           | rhythm     | lead or rhythm | PASS     |
# | The Pale King                     | rhythm     | lead or rhythm | PASS     |
# | You Shook Me All Night Long 2     | rhythm     | lead or rhythm | PASS     |
# | You Shook Me All Night Long 3     | rhythm     | lead or rhythm | PASS     |
# | You Shook Me All Night Long       | rhythm     | lead or rhythm | PASS     |
# +-----------------------------------+------------+----------------+----------+
#
# Pass: 100.0% (60), Fail: 0.0% (0), Total: 60
