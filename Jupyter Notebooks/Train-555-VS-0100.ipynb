# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import normalize, to_categorical
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from numpy import array
import cv2
import os
from prettytable import PrettyTable

# %%
rootPath = './spectrograms2/EQ3/'
imgPath = 'test/'
testImgPath = rootPath + imgPath + os.listdir(rootPath + imgPath)[0]
res = [cv2.imread(testImgPath).shape[0], cv2.imread(testImgPath).shape[1]]

print('Current Resolution: \t' + str(res))

#res = [int(res[0]/2), int(res[1]/2)]
#print('New Resolution: \t' + str(res))

#res = [int(res[0]/1.5), int(res[1]/1.5)]
#print('New Resolution: \t' + str(res))

res = [int(res[0]/4), int(res[1]/4)]
print('New Resolution: \t' + str(res))
# Out:
# Current Resolution: 	[540, 1080]
# New Resolution: 	[135, 270]

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory(
    rootPath + 'train/',
    target_size = (res[0], res[1]),
    batch_size = 10,
    class_mode = 'binary'
)

validation_dataset = validation.flow_from_directory(
    rootPath + 'validate/',
    target_size = (res[0], res[1]),
    batch_size = 10,
    class_mode = 'binary'
)
# Out:
# Found 480 images belonging to 2 classes.
# Found 121 images belonging to 2 classes.

# %%
#print(train_dataset.class_indices)
#print(validation_dataset.class_indices)

# %% [markdown]
# # train generator (rotate images)
#
# train_datagen = ImageDataGenerator(rotation_range=45,
#     width_shift_range=0.2,
#     zoom_range = 0.2,
#     horizontal_flip = True)
# train_datagen.fit(train_dataset)
#
# train_generator = train_datagen.flow(
#     train_dataset,
#     batch_size = 32)

# %%
# old model
activation = 'relu'
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation=activation, input_shape=(res[0], res[1], 3)),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(32,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    ##
    tf.keras.layers.Flatten(),
    ##
    tf.keras.layers.Dense(512, activation=activation),
    ##
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

# %% [markdown]
# activation = 'sigmoid'
# model = Sequential()
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', input_shape = (res[0], res[1], 3)))
# model.add(BatchNormalization())
#
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Flatten())
# model.add(Dense(128, activation = activation, kernel_initializer = 'he_uniform'))
# model.add(Dense(1, activation = 'softmax'))
#
# model.compile(optimizer = 'rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
# print(model.summary())

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(lr=0.001),
    metrics=['accuracy']
)

# %%
model_fit = model.fit(
    train_dataset,
    steps_per_epoch=48,
    epochs=80,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/80
# 48/48 [==============================] - 30s 530ms/step - loss: 0.8382 - accuracy: 0.5007 - val_loss: 0.6932 - val_accuracy: 0.5124
# Epoch 2/80
# 48/48 [==============================] - 26s 538ms/step - loss: 0.6947 - accuracy: 0.4690 - val_loss: 0.6931 - val_accuracy: 0.5620
# Epoch 3/80
# 48/48 [==============================] - 26s 535ms/step - loss: 0.6945 - accuracy: 0.4851 - val_loss: 0.6931 - val_accuracy: 0.5041
# Epoch 4/80
# 48/48 [==============================] - 20s 416ms/step - loss: 0.6938 - accuracy: 0.5321 - val_loss: 0.6926 - val_accuracy: 0.5702
# Epoch 5/80
# 48/48 [==============================] - 26s 529ms/step - loss: 0.7084 - accuracy: 0.5620 - val_loss: 0.5675 - val_accuracy: 0.7851
# Epoch 6/80
# 48/48 [==============================] - 27s 567ms/step - loss: 1.9907e-10 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9835
# Epoch 65/80
# 48/48 [==============================] - 21s 419ms/step - loss: 6.3086e-11 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9835
# Epoch 66/80
# 48/48 [==============================] - 26s 543ms/step - loss: 8.0300e-11 - accuracy: 1.0000 - val_loss: 0.2173 - val_accuracy: 0.9835
# Epoch 67/80
# 48/48 [==============================] - 26s 530ms/step - loss: 1.2053e-10 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9835
# Epoch 68/80
# 48/48 [==============================] - 21s 437ms/step - loss: 8.8521e-11 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9835
# Epoch 69/80
# 48/48 [==============================] - 26s 537ms/step - loss: 6.2106e-11 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9835
# Epoch 70/80
# 48/48 [==============================] - 25s 518ms/step - loss: 9.2938e-11 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9835
# Epoch 71/80
# 48/48 [==============================] - 22s 462ms/step - loss: 9.5408e-11 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9835
# Epoch 72/80
# 48/48 [==============================] - 26s 538ms/step - loss: 1.1251e-10 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9835
# Epoch 73/80
# 48/48 [==============================] - 24s 485ms/step - loss: 8.6464e-11 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9835
# Epoch 74/80
# 48/48 [==============================] - 23s 481ms/step - loss: 1.1610e-10 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9835
# Epoch 75/80
# 48/48 [==============================] - 26s 540ms/step - loss: 1.3109e-10 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9835
# Epoch 76/80
# 48/48 [==============================] - 22s 462ms/step - loss: 1.8692e-10 - accuracy: 1.0000 - val_loss: 0.2333 - val_accuracy: 0.9835
# Epoch 77/80
# 48/48 [==============================] - 24s 503ms/step - loss: 3.3331e-10 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9835
# Epoch 78/80
# 48/48 [==============================] - 26s 533ms/step - loss: 1.4436e-10 - accuracy: 1.0000 - val_loss: 0.2350 - val_accuracy: 0.9835
# Epoch 79/80
# 48/48 [==============================] - 22s 441ms/step - loss: 1.2748e-10 - accuracy: 1.0000 - val_loss: 0.2358 - val_accuracy: 0.9835
# Epoch 80/80
# 48/48 [==============================] - 25s 517ms/step - loss: 9.4280e-11 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9835

# %%
def resultStore(file, pred, results):
    pred = pred.lower()
    if pred in file:
        results[0] = 'PASS'
        results[1] = results[1] + 1
    else:
        results[0] = 'FAIL'
        results[2] = results[2] + 1
    return results

def resultStats(results):
    total = results[1] + results[2]
    p = round(results[1]*100/total, 2)
    f = round(results[2]*100/total, 2)
    return 'Pass: ' + str(p) + '% (' + str(results[1]) + '), Fail: ' + str(f) + '% (' + str(results[2]) + '), Total: ' + str(total)

# %%
validation_dataset.class_indices
classes = {v: k for k, v in validation_dataset.class_indices.items()}
print(classes)
# Out:
# {0: '0-10-0', 1: '5-5-5'}

# %% [markdown]
# testPath = rootPath + 'test/'
# results = ["", 0, 0]
#
# table = PrettyTable()
# table.field_names = ["1", "File", "2", "Class", "3", "Prediction", "4", "Result", " "]
#
# for i in os.listdir(testPath):
#     img = image.load_img(
#         testPath + '//' + i,
#         target_size = (res[0], res[1])
#     )
#
#     X = image.img_to_array(img)
#     X = np.expand_dims(X, axis=0)
#     images = np.vstack([X])
#     prediction = int(model.predict(images))
#
#     results = resultStore(i, classes[prediction][3:-4], results)
#     splt = i.split('_session_')
#     clss = splt[0]
#     fname = splt[1].replace('_', ' ')
#     table.add_row(["", fname[:-4], "", clss, "", classes[prediction][3:-4], "", results[0], ""])
#
# table.align = 'l'
# print(table)
#
# print('\n' + resultStats(results))

# %%
def get_precision(prec, result):
    if result == "PASS":
        prec[0] = prec[0] + 1
        prec[1] = prec[1] + 1
    else:
        prec[1] = prec[1] + 1
    return prec

def get_recall(rec, result, clss):
    if clss == 0:
        if result == "PASS":
            rec[0] = rec[0] + 1
            rec[1] = rec[1] + 1
        else:
            rec[3] = rec[3] + 1
    else:
        if result == "PASS":
            rec[2] = rec[2] + 1
            rec[3] = rec[3] + 1
        else:
            rec[1] = rec[1] + 1
    return rec

def get_fscore(prec, rec):
    return 2 * ((prec * rec) / (prec + rec))

def get_metrics(precision1, precision2, recall, classes):
    precision = [round((precision1[0]/precision1[1]), 2)*100, round((precision2[0]/precision2[1]), 2)*100]
    recall = [round((recall[0]/recall[1]), 2)*100, round((recall[2]/recall[3]), 2)*100]
    fscore = [round(get_fscore(precision[0], recall[0]),2), round(get_fscore(precision[1], recall[1]),2)]

    metrics.table = PrettyTable()
    metrics.table.field_names = ["Classes", "Precision", "Recall", "F-Score"]
    return matrix

# %%
recall = [0,0,0,0]
precision1 = [0,0]
precision2 = [0,0]
fscore = [0,0]

testPath = rootPath + 'test/'
results = ["", 0, 0]

table = PrettyTable()
table.field_names = ["File", "Class", "Prediction", "Result"]

for i in os.listdir(testPath):
    img = image.load_img(
        testPath + '//' + i,
        target_size = (res[0], res[1])
    )

    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    prediction = int(model.predict(images))
    
    results = resultStore(i, classes[prediction], results)
    splt = i.split('_session_')
    clss = splt[0]
    fname = splt[1].replace('_', ' ')
    table.add_row([fname[:-4] + "    ", clss + "    ", classes[prediction], results[0] + "    "])

    if(prediction==0):
        precision1 = get_precision(precision1, results[0])
        recall = get_recall(recall, results[0], prediction)
    else:
        precision2 = get_precision(precision2, results[0])
        recall = get_recall(recall, results[0], prediction)

table.align = 'l'
print(table)

print('\n' + resultStats(results))

print(get_metrics(precision1, precision2, recall, classes))

precision = [round((precision1[0]/precision1[1]), 2)*100, round((precision2[0]/precision2[1]), 2)*100]
recall = [round((recall[0]/recall[1]), 2)*100, round((recall[2]/recall[3]), 2)*100]
fscore = [round(get_fscore(precision[0], recall[0]),2), round(get_fscore(precision[1], recall[1]),2)]

print('\n' + 'Precision ' + classes[0] + ': ' + str(precision[0]) + ' - Precision ' + classes[1] + ': ' + str(precision[1]))

print('\n' + 'Recall ' + classes[0] + ': ' + str(recall[0]) + ' - Recall ' + classes[1] + ': ' + str(recall[1]))

print('\n' + 'F-score ' + classes[0] + ': ' + str(fscore[0]) + ' - F-score ' + classes[1] + ': ' + str(fscore[1]))
# Out:
# +-----------------------------+-------------------+------------+----------+
# | File                        | Class             | Prediction | Result   |
# +-----------------------------+-------------------+------------+----------+
# | 2 Minutes To Midnight 2     | clean-0-10-0      | 0-10-0     | PASS     |
# | 2 Minutes To Midnight       | clean-0-10-0      | 0-10-0     | PASS     |
# | 8 Strings Low 2             | clean-0-10-0      | 0-10-0     | PASS     |
# | 8 Strings Low               | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 51                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 52                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 53                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 54                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 55                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 56                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 57                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 58                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 59                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Audio 60                    | clean-0-10-0      | 0-10-0     | PASS     |
# | Bloodline                   | clean-0-10-0      | 0-10-0     | PASS     |
# | Bloodline2                  | clean-0-10-0      | 0-10-0     | PASS     |
# | Chords 1 -2                 | clean-0-10-0      | 0-10-0     | PASS     |
# | Chords 2 -2                 | clean-0-10-0      | 0-10-0     | PASS     |
# | Chords 3 -2                 | clean-0-10-0      | 0-10-0     | PASS     |
# | Chords 1                    | clean-0-10-0      | 0-10-0     | PASS     |
# | 2 Minutes To Midnight 2     | clean-5-5-5       | 5-5-5      | PASS     |
# | 2 Minutes To Midnight       | clean-5-5-5       | 5-5-5      | PASS     |
# | 8 Strings Low 2             | clean-5-5-5       | 5-5-5      | PASS     |
# | 8 Strings Low               | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 41                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 42                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 43                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 44                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 45                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 46                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 47                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 48                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 49                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Audio 50                    | clean-5-5-5       | 5-5-5      | PASS     |
# | Bloodline                   | clean-5-5-5       | 5-5-5      | PASS     |
# | Bloodline2                  | clean-5-5-5       | 5-5-5      | PASS     |
# | Chords 1 -2                 | clean-5-5-5       | 5-5-5      | PASS     |
# | Chords 2 -2                 | clean-5-5-5       | 5-5-5      | PASS     |
# | Chords 3 -2                 | clean-5-5-5       | 5-5-5      | PASS     |
# | Chords 1                    | clean-5-5-5       | 5-5-5      | PASS     |
# | 2 Minutes To Midnight 2     | lead-0-10-0       | 0-10-0     | PASS     |
# | 2 Minutes To Midnight       | lead-0-10-0       | 0-10-0     | PASS     |
# | 8 Strings Low 2             | lead-0-10-0       | 0-10-0     | PASS     |
# | 8 Strings Low               | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 51                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 52                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 53                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 54                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 55                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 56                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 57                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 58                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 59                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Audio 60                    | lead-0-10-0       | 0-10-0     | PASS     |
# | Bloodline                   | lead-0-10-0       | 0-10-0     | PASS     |
# | Bloodline2                  | lead-0-10-0       | 0-10-0     | PASS     |
# | Chords 1 -2                 | lead-0-10-0       | 0-10-0     | PASS     |
# | Chords 2 -2                 | lead-0-10-0       | 0-10-0     | PASS     |
# | Chords 3 -2                 | lead-0-10-0       | 0-10-0     | PASS     |
# | Chords 1                    | lead-0-10-0       | 0-10-0     | PASS     |
# | 2 Minutes To Midnight 2     | lead-5-5-5        | 5-5-5      | PASS     |
# | 2 Minutes To Midnight       | lead-5-5-5        | 5-5-5      | PASS     |
# | 8 Strings Low 2             | lead-5-5-5        | 5-5-5      | PASS     |
# | 8 Strings Low               | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 41                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 42                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 43                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 44                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 45                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 46                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 47                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 48                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 49                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Audio 50                    | lead-5-5-5        | 5-5-5      | PASS     |
# | Bloodline                   | lead-5-5-5        | 5-5-5      | PASS     |
# | Bloodline2                  | lead-5-5-5        | 5-5-5      | PASS     |
# | Chords 1 -2                 | lead-5-5-5        | 5-5-5      | PASS     |
# | Chords 2 -2                 | lead-5-5-5        | 5-5-5      | PASS     |
# | Chords 3 -2                 | lead-5-5-5        | 5-5-5      | PASS     |
# | Chords 1                    | lead-5-5-5        | 5-5-5      | PASS     |
# | 2 Minutes To Midnight 2     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | 2 Minutes To Midnight       | rhythm-0-10-0     | 0-10-0     | PASS     |
# | 8 Strings Low 2             | rhythm-0-10-0     | 0-10-0     | PASS     |
# | 8 Strings Low               | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 1                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 10                    | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 2                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 3                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 4                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 5                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 6                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 7                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 8                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Audio 9                     | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Bloodline                   | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Bloodline2                  | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Chords 1 -2                 | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Chords 2 -2                 | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Chords 3 -2                 | rhythm-0-10-0     | 0-10-0     | PASS     |
# | Chords 1                    | rhythm-0-10-0     | 0-10-0     | PASS     |
# | 2 Minutes To Midnight 2     | rhythm-5-5-5      | 5-5-5      | PASS     |
# | 2 Minutes To Midnight       | rhythm-5-5-5      | 5-5-5      | PASS     |
# | 8 Strings Low 2             | rhythm-5-5-5      | 5-5-5      | PASS     |
# | 8 Strings Low               | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 41                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 42                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 43                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 44                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 45                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 46                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 47                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 48                    | rhythm-5-5-5      | 0-10-0     | FAIL     |
# | Audio 49                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Audio 50                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Bloodline                   | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Bloodline2                  | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Chords 1 -2                 | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Chords 2 -2                 | rhythm-5-5-5      | 0-10-0     | FAIL     |
# | Chords 3 -2                 | rhythm-5-5-5      | 5-5-5      | PASS     |
# | Chords 1                    | rhythm-5-5-5      | 5-5-5      | PASS     |
# +-----------------------------+-------------------+------------+----------+
#
# Pass: 98.33% (118), Fail: 1.67% (2), Total: 120
# [['' 'Precision' 'Recall' 'F-Score']
#  ['0-10-0' '97.0' '100.0' '98.48']
#  ['5-5-5' '100.0' '97.0' '98.48']]
#
# Precision 0-10-0: 97.0 - Precision 5-5-5: 100.0
#
# Recall 0-10-0: 100.0 - Recall 5-5-5: 97.0
#
# F-score 0-10-0: 98.48 - F-score 5-5-5: 98.48

# %%
#plot the training and validation accuracy and loss at each epoch
plt.subplot(1, 2, 1)
loss = model_fit.history['loss']
val_loss = model_fit.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'royalblue', label='Training loss')
plt.plot(epochs, val_loss, 'coral', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
acc = model_fit.history['accuracy']
val_acc = model_fit.history['val_accuracy']
plt.plot(epochs, acc, 'royalblue', label='Training acc')
plt.plot(epochs, val_acc, 'coral', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.rcParams['figure.figsize'] = [12, 5]
plt.tight_layout()
plt.savefig("test.pdf", format="pdf")
plt.show()

# %%
#model.save('eq3.h5')
