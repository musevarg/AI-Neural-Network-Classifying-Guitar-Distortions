# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import normalize, to_categorical
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from prettytable import PrettyTable

# %%
rootPath = './spectrograms2/EQ2/'
imgPath = 'test/'
testImgPath = rootPath + imgPath + os.listdir(rootPath + imgPath)[0]
res = [cv2.imread(testImgPath).shape[0], cv2.imread(testImgPath).shape[1]]

print('Current Resolution: \t' + str(res))

#res = [int(res[0]/2), int(res[1]/2)]
#print('New Resolution: \t' + str(res))

#res = [int(res[0]/1.5), int(res[1]/1.5)]
#print('New Resolution: \t' + str(res))

res = [int(res[0]/4), int(res[1]/4)]
print('New Resolution: \t' + str(res))
# Out:
# Current Resolution: 	[540, 1080]
# New Resolution: 	[135, 270]

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory(
    rootPath + 'train/',
    target_size = (res[0], res[1]),
    batch_size = 10,
    class_mode = 'binary'
)

validation_dataset = validation.flow_from_directory(
    rootPath + 'validate/',
    target_size = (res[0], res[1]),
    batch_size = 10,
    class_mode = 'binary'
)
# Out:
# Found 480 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %%
#print(train_dataset.class_indices)
#print(validation_dataset.class_indices)

# %% [markdown]
# # train generator (rotate images)
#
# train_datagen = ImageDataGenerator(rotation_range=45,
#     width_shift_range=0.2,
#     zoom_range = 0.2,
#     horizontal_flip = True)
# train_datagen.fit(train_dataset)
#
# train_generator = train_datagen.flow(
#     train_dataset,
#     batch_size = 32)

# %%
# old model
activation = 'relu'
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation=activation, input_shape=(res[0], res[1], 3)),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(32,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    ##
    tf.keras.layers.Flatten(),
    ##
    tf.keras.layers.Dense(512, activation=activation),
    ##
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

# %% [markdown]
# activation = 'sigmoid'
# model = Sequential()
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', input_shape = (res[0], res[1], 3)))
# model.add(BatchNormalization())
#
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Flatten())
# model.add(Dense(128, activation = activation, kernel_initializer = 'he_uniform'))
# model.add(Dense(1, activation = 'softmax'))
#
# model.compile(optimizer = 'rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
# print(model.summary())

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(lr=0.001),
    metrics=['accuracy']
)

# %%
model_fit = model.fit(
    train_dataset,
    steps_per_epoch=48,
    epochs=75,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/75
# 48/48 [==============================] - 17s 326ms/step - loss: 1.2263 - accuracy: 0.6761 - val_loss: 0.0590 - val_accuracy: 0.9833
# Epoch 2/75
# 48/48 [==============================] - 13s 277ms/step - loss: 0.1406 - accuracy: 0.9580 - val_loss: 0.1652 - val_accuracy: 0.9417
# Epoch 3/75
# 48/48 [==============================] - 13s 278ms/step - loss: 0.1200 - accuracy: 0.9608 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 4/75
# 48/48 [==============================] - 13s 278ms/step - loss: 0.1533 - accuracy: 0.9568 - val_loss: 0.0810 - val_accuracy: 0.9917
# Epoch 5/75
# 48/48 [==============================] - 14s 281ms/step - loss: 0.0415 - accuracy: 0.9941 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 6/75
# 48/48 [==============================] - 14s 293ms/step - loss: 0.0467 - accuracy: 0.9881 - val_loss: 0.0101 - val_accuracy: 0.9917
# Epoch 7/75
# 48/48 [==============================] - 14s 284ms/step - loss: 0.0146 - accuracy: 0.9966 - val_loss: 1.1809e-04 - val_accuracy: 1.0000
# Epoch 8/75
# 48/48 [==============================] - 15s 316ms/step - loss: 0.0206 - accuracy: 0.9982 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 9/75
# 48/48 [==============================] - 22s 452ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 2.2950e-04 - val_accuracy: 1.0000
# Epoch 10/75
# 48/48 [==============================] - 21s 442ms/step - loss: 8.8044e-04 - accuracy: 1.0000 - val_loss: 5.2963e-05 - val_accuracy: 1.0000
# Epoch 11/75
# 48/48 [==============================] - 25s 512ms/step - loss: 0.0196 - accuracy: 0.9974 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 12/75
# 48/48 [==============================] - 26s 535ms/step - loss: 7.2232e-04 - accuracy: 1.0000 - val_loss: 2.4710e-04 - val_accuracy: 1.0000
# Epoch 13/75
# 48/48 [==============================] - 25s 525ms/step - loss: 4.5004e-04 - accuracy: 0.9999 - val_loss: 0.1564 - val_accuracy: 0.9750
# Epoch 14/75
# 48/48 [==============================] - 23s 473ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1746e-05 - val_accuracy: 1.0000
# Epoch 15/75
# 48/48 [==============================] - 16s 330ms/step - loss: 0.0788 - accuracy: 0.9896 - val_loss: 1.5943e-05 - val_accuracy: 1.0000
# Epoch 16/75
# 48/48 [==============================] - 24s 506ms/step - loss: 1.2021e-04 - accuracy: 1.0000 - val_loss: 1.4287e-05 - val_accuracy: 1.0000
# Epoch 17/75
# 48/48 [==============================] - 23s 473ms/step - loss: 9.1674e-06 - accuracy: 1.0000 - val_loss: 1.1535e-06 - val_accuracy: 1.0000
# Epoch 18/75
# 48/48 [==============================] - 26s 541ms/step - loss: 0.0116 - accuracy: 0.9930 - val_loss: 4.0304e-05 - val_accuracy: 1.0000
# Epoch 19/75
# 48/48 [==============================] - 26s 542ms/step - loss: 1.2945e-06 - accuracy: 1.0000 - val_loss: 2.7135e-05 - val_accuracy: 1.0000
# Epoch 20/75
# 48/48 [==============================] - 26s 538ms/step - loss: 4.0142e-07 - accuracy: 1.0000 - val_loss: 1.9559e-07 - val_accuracy: 1.0000
# Epoch 21/75
# 48/48 [==============================] - 26s 546ms/step - loss: 1.0508e-07 - accuracy: 1.0000 - val_loss: 6.3761e-07 - val_accuracy: 1.0000
# Epoch 22/75
# 48/48 [==============================] - 26s 536ms/step - loss: 2.2652e-09 - accuracy: 1.0000 - val_loss: 2.6438e-07 - val_accuracy: 1.0000
# Epoch 23/75
# 48/48 [==============================] - 26s 538ms/step - loss: 5.1733e-10 - accuracy: 1.0000 - val_loss: 9.0788e-08 - val_accuracy: 1.0000
# Epoch 24/75
# 48/48 [==============================] - 26s 534ms/step - loss: 1.3195e-10 - accuracy: 1.0000 - val_loss: 1.4261e-07 - val_accuracy: 1.0000
# Epoch 25/75
# 48/48 [==============================] - 26s 548ms/step - loss: 2.6059e-10 - accuracy: 1.0000 - val_loss: 5.0688e-07 - val_accuracy: 1.0000
# Epoch 26/75
# 48/48 [==============================] - 26s 537ms/step - loss: 9.7610e-11 - accuracy: 1.0000 - val_loss: 1.9088e-09 - val_accuracy: 1.0000
# Epoch 27/75
# 48/48 [==============================] - 27s 551ms/step - loss: 3.2856e-10 - accuracy: 1.0000 - val_loss: 5.5432e-07 - val_accuracy: 1.0000
# Epoch 28/75
# 48/48 [==============================] - 26s 540ms/step - loss: 0.0357 - accuracy: 0.9982 - val_loss: 1.3627e-07 - val_accuracy: 1.0000
# Epoch 29/75
# 48/48 [==============================] - 26s 540ms/step - loss: 5.4041e-08 - accuracy: 1.0000 - val_loss: 1.4468e-07 - val_accuracy: 1.0000
# Epoch 30/75
# 48/48 [==============================] - 26s 536ms/step - loss: 1.8432e-09 - accuracy: 1.0000 - val_loss: 4.3074e-07 - val_accuracy: 1.0000
# Epoch 31/75
# 48/48 [==============================] - 26s 544ms/step - loss: 9.8666e-10 - accuracy: 1.0000 - val_loss: 9.8714e-07 - val_accuracy: 1.0000
# Epoch 32/75
# 48/48 [==============================] - 26s 538ms/step - loss: 1.9077e-09 - accuracy: 1.0000 - val_loss: 1.3644e-06 - val_accuracy: 1.0000
# Epoch 33/75
# 48/48 [==============================] - 26s 535ms/step - loss: 1.4131e-09 - accuracy: 1.0000 - val_loss: 1.7261e-06 - val_accuracy: 1.0000
# Epoch 34/75
# 48/48 [==============================] - 26s 535ms/step - loss: 3.5180e-10 - accuracy: 1.0000 - val_loss: 1.6059e-06 - val_accuracy: 1.0000
# Epoch 35/75
# 48/48 [==============================] - 26s 540ms/step - loss: 4.8152e-10 - accuracy: 1.0000 - val_loss: 1.0998e-07 - val_accuracy: 1.0000
# Epoch 36/75
# 48/48 [==============================] - 26s 539ms/step - loss: 1.9759e-12 - accuracy: 1.0000 - val_loss: 1.1227e-07 - val_accuracy: 1.0000
# Epoch 37/75
# 48/48 [==============================] - 26s 541ms/step - loss: 1.9548e-12 - accuracy: 1.0000 - val_loss: 1.1449e-07 - val_accuracy: 1.0000
# Epoch 38/75
# 48/48 [==============================] - 26s 540ms/step - loss: 3.5395e-12 - accuracy: 1.0000 - val_loss: 1.1660e-07 - val_accuracy: 1.0000
# Epoch 39/75
# 48/48 [==============================] - 26s 547ms/step - loss: 3.6470e-12 - accuracy: 1.0000 - val_loss: 1.1862e-07 - val_accuracy: 1.0000
# Epoch 40/75
# 48/48 [==============================] - 25s 527ms/step - loss: 2.7919e-12 - accuracy: 1.0000 - val_loss: 1.2054e-07 - val_accuracy: 1.0000
# Epoch 41/75
# 48/48 [==============================] - 25s 523ms/step - loss: 5.8697e-12 - accuracy: 1.0000 - val_loss: 1.2239e-07 - val_accuracy: 1.0000
# Epoch 42/75
# 48/48 [==============================] - 25s 521ms/step - loss: 2.3500e-12 - accuracy: 1.0000 - val_loss: 1.2415e-07 - val_accuracy: 1.0000
# Epoch 43/75
# 48/48 [==============================] - 25s 518ms/step - loss: 1.7737e-12 - accuracy: 1.0000 - val_loss: 1.2585e-07 - val_accuracy: 1.0000
# Epoch 44/75
# 48/48 [==============================] - 25s 521ms/step - loss: 4.1771e-12 - accuracy: 1.0000 - val_loss: 1.2749e-07 - val_accuracy: 1.0000
# Epoch 45/75
# 48/48 [==============================] - 25s 511ms/step - loss: 1.5529e-12 - accuracy: 1.0000 - val_loss: 1.2907e-07 - val_accuracy: 1.0000
# Epoch 46/75
# 48/48 [==============================] - 26s 527ms/step - loss: 3.1332e-12 - accuracy: 1.0000 - val_loss: 1.3059e-07 - val_accuracy: 1.0000
# Epoch 47/75
# 48/48 [==============================] - 26s 528ms/step - loss: 1.8490e-12 - accuracy: 1.0000 - val_loss: 1.3208e-07 - val_accuracy: 1.0000
# Epoch 48/75
# 48/48 [==============================] - 25s 524ms/step - loss: 1.8212e-12 - accuracy: 1.0000 - val_loss: 1.3353e-07 - val_accuracy: 1.0000
# Epoch 49/75
# 48/48 [==============================] - 25s 518ms/step - loss: 2.2343e-12 - accuracy: 1.0000 - val_loss: 1.3495e-07 - val_accuracy: 1.0000
# Epoch 50/75
# 48/48 [==============================] - 25s 524ms/step - loss: 4.3483e-12 - accuracy: 1.0000 - val_loss: 1.3635e-07 - val_accuracy: 1.0000
# Epoch 51/75
# 48/48 [==============================] - 25s 513ms/step - loss: 2.6727e-12 - accuracy: 1.0000 - val_loss: 1.3771e-07 - val_accuracy: 1.0000
# Epoch 52/75
# 48/48 [==============================] - 25s 521ms/step - loss: 2.6444e-12 - accuracy: 1.0000 - val_loss: 1.3905e-07 - val_accuracy: 1.0000
# Epoch 53/75
# 48/48 [==============================] - 25s 520ms/step - loss: 1.6468e-12 - accuracy: 1.0000 - val_loss: 1.4037e-07 - val_accuracy: 1.0000
# Epoch 54/75
# 48/48 [==============================] - 25s 523ms/step - loss: 4.7117e-12 - accuracy: 1.0000 - val_loss: 1.4166e-07 - val_accuracy: 1.0000
# Epoch 55/75
# 48/48 [==============================] - 26s 528ms/step - loss: 3.3366e-12 - accuracy: 1.0000 - val_loss: 1.4292e-07 - val_accuracy: 1.0000
# Epoch 56/75
# 48/48 [==============================] - 26s 535ms/step - loss: 3.8758e-12 - accuracy: 1.0000 - val_loss: 1.4416e-07 - val_accuracy: 1.0000
# Epoch 57/75
# 48/48 [==============================] - 26s 532ms/step - loss: 2.4803e-12 - accuracy: 1.0000 - val_loss: 1.4537e-07 - val_accuracy: 1.0000
# Epoch 58/75
# 48/48 [==============================] - 26s 537ms/step - loss: 1.8512e-12 - accuracy: 1.0000 - val_loss: 1.4656e-07 - val_accuracy: 1.0000
# Epoch 59/75
# 48/48 [==============================] - 26s 531ms/step - loss: 3.5038e-12 - accuracy: 1.0000 - val_loss: 1.4772e-07 - val_accuracy: 1.0000
# Epoch 60/75
# 48/48 [==============================] - 25s 519ms/step - loss: 3.4539e-12 - accuracy: 1.0000 - val_loss: 1.4887e-07 - val_accuracy: 1.0000
# Epoch 61/75
# 48/48 [==============================] - 25s 523ms/step - loss: 7.3414e-12 - accuracy: 1.0000 - val_loss: 1.4999e-07 - val_accuracy: 1.0000
# Epoch 62/75
# 48/48 [==============================] - 25s 523ms/step - loss: 1.8854e-12 - accuracy: 1.0000 - val_loss: 1.5110e-07 - val_accuracy: 1.0000
# Epoch 63/75
# 48/48 [==============================] - 26s 531ms/step - loss: 3.5681e-12 - accuracy: 1.0000 - val_loss: 1.5219e-07 - val_accuracy: 1.0000
# Epoch 64/75
# 48/48 [==============================] - 26s 533ms/step - loss: 4.1515e-12 - accuracy: 1.0000 - val_loss: 1.5327e-07 - val_accuracy: 1.0000
# Epoch 65/75
# 48/48 [==============================] - 26s 530ms/step - loss: 1.9040e-12 - accuracy: 1.0000 - val_loss: 1.5433e-07 - val_accuracy: 1.0000
# Epoch 66/75
# 48/48 [==============================] - 25s 533ms/step - loss: 2.6447e-12 - accuracy: 1.0000 - val_loss: 1.5537e-07 - val_accuracy: 1.0000
# Epoch 67/75
# 48/48 [==============================] - 25s 529ms/step - loss: 4.1746e-12 - accuracy: 1.0000 - val_loss: 1.5640e-07 - val_accuracy: 1.0000
# Epoch 68/75
# 48/48 [==============================] - 25s 529ms/step - loss: 4.8090e-12 - accuracy: 1.0000 - val_loss: 1.5742e-07 - val_accuracy: 1.0000
# Epoch 69/75
# 48/48 [==============================] - 25s 530ms/step - loss: 1.6272e-12 - accuracy: 1.0000 - val_loss: 1.5842e-07 - val_accuracy: 1.0000
# Epoch 70/75
# 48/48 [==============================] - 26s 532ms/step - loss: 3.1424e-12 - accuracy: 1.0000 - val_loss: 1.5942e-07 - val_accuracy: 1.0000
# Epoch 71/75
# 48/48 [==============================] - 25s 529ms/step - loss: 3.8029e-12 - accuracy: 1.0000 - val_loss: 1.6040e-07 - val_accuracy: 1.0000
# Epoch 72/75
# 48/48 [==============================] - 26s 540ms/step - loss: 3.3451e-12 - accuracy: 1.0000 - val_loss: 1.6137e-07 - val_accuracy: 1.0000
# Epoch 73/75
# 48/48 [==============================] - 25s 531ms/step - loss: 4.3435e-12 - accuracy: 1.0000 - val_loss: 1.6233e-07 - val_accuracy: 1.0000
# Epoch 74/75
# 48/48 [==============================] - 25s 533ms/step - loss: 3.8087e-12 - accuracy: 1.0000 - val_loss: 1.6328e-07 - val_accuracy: 1.0000
# Epoch 75/75
# 48/48 [==============================] - 25s 527ms/step - loss: 2.0090e-12 - accuracy: 1.0000 - val_loss: 1.6422e-07 - val_accuracy: 1.0000

# %%
def resultStore(file, pred, results):
    pred = pred.lower()
    if pred in file:
        results[0] = 'PASS'
        results[1] = results[1] + 1
    else:
        results[0] = 'FAIL'
        results[2] = results[2] + 1
    return results

def resultStats(results):
    total = results[1] + results[2]
    p = round(results[1]*100/total, 2)
    f = round(results[2]*100/total, 2)
    return 'Pass: ' + str(p) + '% (' + str(results[1]) + '), Fail: ' + str(f) + '% (' + str(results[2]) + '), Total: ' + str(total)

# %%
validation_dataset.class_indices
classes = {v: k for k, v in validation_dataset.class_indices.items()}
print(classes)
# Out:
# {0: '0-0-10', 1: '10-0-0'}

# %% [markdown]
# testPath = rootPath + 'test/'
# results = ["", 0, 0]
#
# table = PrettyTable()
# table.field_names = ["1", "File", "2", "Class", "3", "Prediction", "4", "Result", " "]
#
# for i in os.listdir(testPath):
#     img = image.load_img(
#         testPath + '//' + i,
#         target_size = (res[0], res[1])
#     )
#
#     X = image.img_to_array(img)
#     X = np.expand_dims(X, axis=0)
#     images = np.vstack([X])
#     prediction = int(model.predict(images))
#
#     results = resultStore(i, classes[prediction][3:-4], results)
#     splt = i.split('_session_')
#     clss = splt[0]
#     fname = splt[1].replace('_', ' ')
#     table.add_row(["", fname[:-4], "", clss, "", classes[prediction][3:-4], "", results[0], ""])
#
# table.align = 'l'
# print(table)
#
# print('\n' + resultStats(results))

# %%
def get_precision(prec, result):
    if result == "PASS":
        prec[0] = prec[0] + 1
        prec[1] = prec[1] + 1
    else:
        prec[1] = prec[1] + 1
    return prec

def get_recall(rec, result, clss):
    if clss == 0:
        if result == "PASS":
            rec[0] = rec[0] + 1
            rec[1] = rec[1] + 1
        else:
            rec[3] = rec[3] + 1
    else:
        if result == "PASS":
            rec[2] = rec[2] + 1
            rec[3] = rec[3] + 1
        else:
            rec[1] = rec[1] + 1
    return rec

def get_fscore(prec, rec):
    return 2 * ((prec * rec) / (prec + rec))

def get_metrics(precision1, precision2, recall, classes):
    precision = [round((precision1[0]/precision1[1]), 2)*100, round((precision2[0]/precision2[1]), 2)*100]
    recall = [round((recall[0]/recall[1]), 2)*100, round((recall[2]/recall[3]), 2)*100]
    fscore = [round(get_fscore(precision[0], recall[0]),2), round(get_fscore(precision[1], recall[1]),2)]

    metrics_table = PrettyTable()
    metrics_table.field_names = ["Class", "Precision", "Recall", "F-Score"]
    for i in classes:
        metrics_table.add_row([classes[i], precision[i], recall[i], fscore[i]])
    return metrics_table

# %%
recall = [0,0,0,0]
precision1 = [0,0]
precision2 = [0,0]
fscore = [0,0]

testPath = rootPath + 'test/'
results = ["", 0, 0]

table = PrettyTable()
table.field_names = ["File", "Class", "Prediction", "Result"]

for i in os.listdir(testPath):
    img = image.load_img(
        testPath + '//' + i,
        target_size = (res[0], res[1])
    )

    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    prediction = int(model.predict(images))
    
    results = resultStore(i, classes[prediction], results)
    splt = i.split('_session_')
    clss = splt[0]
    fname = splt[1].replace('_', ' ')
    table.add_row([fname[:-4] + "    ", clss + "    ", classes[prediction], results[0] + "    "])

    if(prediction==0):
        precision1 = get_precision(precision1, results[0])
        recall = get_recall(recall, results[0], prediction)
    else:
        precision2 = get_precision(precision2, results[0])
        recall = get_recall(recall, results[0], prediction)

table.align = 'l'
print(table)

print('\n' + resultStats(results))

print(get_metrics(precision1, precision2, recall, classes))
# Out:
# +-----------------------------------+-------------------+------------+----------+
# | File                              | Class             | Prediction | Result   |
# +-----------------------------------+-------------------+------------+----------+
# | Audio 51                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 52                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 53                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 54                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 55                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 56                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 57                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 58                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 59                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Audio 60                          | clean-0-0-10      | 0-0-10     | PASS     |
# | Soundcloud 10                     | clean-0-0-10      | 0-0-10     | PASS     |
# | The Call Of Ktulu 2               | clean-0-0-10      | 0-0-10     | PASS     |
# | The Number Of The Beast 2         | clean-0-0-10      | 0-0-10     | PASS     |
# | The Pale King 2                   | clean-0-0-10      | 0-0-10     | PASS     |
# | The Call Of Ktulu                 | clean-0-0-10      | 0-0-10     | PASS     |
# | The Number Of The Beast           | clean-0-0-10      | 0-0-10     | PASS     |
# | The Pale King                     | clean-0-0-10      | 0-0-10     | PASS     |
# | You Shook Me All Night Long 2     | clean-0-0-10      | 0-0-10     | PASS     |
# | You Shook Me All Night Long 3     | clean-0-0-10      | 0-0-10     | PASS     |
# | You Shook Me All Night Long       | clean-0-0-10      | 0-0-10     | PASS     |
# | 2 Minutes To Midnight 2           | clean-10-0-0      | 10-0-0     | PASS     |
# | 2 Minutes To Midnight             | clean-10-0-0      | 10-0-0     | PASS     |
# | 8 Strings Low 2                   | clean-10-0-0      | 10-0-0     | PASS     |
# | 8 Strings Low                     | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 1                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 10                          | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 2                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 3                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 4                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 5                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 6                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 7                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 8                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Audio 9                           | clean-10-0-0      | 10-0-0     | PASS     |
# | Bloodline                         | clean-10-0-0      | 10-0-0     | PASS     |
# | Bloodline2                        | clean-10-0-0      | 10-0-0     | PASS     |
# | Chords 1 -2                       | clean-10-0-0      | 10-0-0     | PASS     |
# | Chords 2 -2                       | clean-10-0-0      | 10-0-0     | PASS     |
# | Chords 3 -2                       | clean-10-0-0      | 10-0-0     | PASS     |
# | Chords 1                          | clean-10-0-0      | 10-0-0     | PASS     |
# | 2 Minutes To Midnight 2           | lead-0-0-10       | 0-0-10     | PASS     |
# | 2 Minutes To Midnight             | lead-0-0-10       | 0-0-10     | PASS     |
# | 8 Strings Low 2                   | lead-0-0-10       | 0-0-10     | PASS     |
# | 8 Strings Low                     | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 1                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 10                          | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 2                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 3                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 4                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 5                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 6                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 7                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 8                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Audio 9                           | lead-0-0-10       | 0-0-10     | PASS     |
# | Bloodline                         | lead-0-0-10       | 0-0-10     | PASS     |
# | The Number Of The Beast           | lead-0-0-10       | 0-0-10     | PASS     |
# | The Pale King                     | lead-0-0-10       | 0-0-10     | PASS     |
# | You Shook Me All Night Long 2     | lead-0-0-10       | 0-0-10     | PASS     |
# | You Shook Me All Night Long 3     | lead-0-0-10       | 0-0-10     | PASS     |
# | You Shook Me All Night Long       | lead-0-0-10       | 0-0-10     | PASS     |
# | 2 Minutes To Midnight 2           | lead-10-0-0       | 10-0-0     | PASS     |
# | 2 Minutes To Midnight             | lead-10-0-0       | 10-0-0     | PASS     |
# | 8 Strings Low 2                   | lead-10-0-0       | 10-0-0     | PASS     |
# | 8 Strings Low                     | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 51                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 52                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 53                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 54                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 55                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 56                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 57                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 58                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 59                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 60                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Bloodline                         | lead-10-0-0       | 10-0-0     | PASS     |
# | Bloodline2                        | lead-10-0-0       | 10-0-0     | PASS     |
# | Chords 1 -2                       | lead-10-0-0       | 10-0-0     | PASS     |
# | Chords 2 -2                       | lead-10-0-0       | 10-0-0     | PASS     |
# | Chords 3 -2                       | lead-10-0-0       | 10-0-0     | PASS     |
# | Chords 1                          | lead-10-0-0       | 10-0-0     | PASS     |
# | Audio 1                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 10                          | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 2                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 3                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 4                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 5                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 6                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 7                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 8                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Audio 9                           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | Soundcloud 10                     | rhythm-0-0-10     | 0-0-10     | PASS     |
# | The Call Of Ktulu 2               | rhythm-0-0-10     | 0-0-10     | PASS     |
# | The Number Of The Beast 2         | rhythm-0-0-10     | 0-0-10     | PASS     |
# | The Pale King 2                   | rhythm-0-0-10     | 0-0-10     | PASS     |
# | The Call Of Ktulu                 | rhythm-0-0-10     | 0-0-10     | PASS     |
# | The Number Of The Beast           | rhythm-0-0-10     | 0-0-10     | PASS     |
# | The Pale King                     | rhythm-0-0-10     | 0-0-10     | PASS     |
# | You Shook Me All Night Long 2     | rhythm-0-0-10     | 0-0-10     | PASS     |
# | You Shook Me All Night Long 3     | rhythm-0-0-10     | 0-0-10     | PASS     |
# | You Shook Me All Night Long       | rhythm-0-0-10     | 0-0-10     | PASS     |
# | 2 Minutes To Midnight 2           | rhythm-10-0-0     | 10-0-0     | PASS     |
# | 2 Minutes To Midnight             | rhythm-10-0-0     | 10-0-0     | PASS     |
# | 8 Strings Low 2                   | rhythm-10-0-0     | 10-0-0     | PASS     |
# | 8 Strings Low                     | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 51                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 52                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 53                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 54                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 55                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 56                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 57                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 58                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 59                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Audio 60                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Bloodline                         | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Bloodline2                        | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Chords 1 -2                       | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Chords 2 -2                       | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Chords 3 -2                       | rhythm-10-0-0     | 10-0-0     | PASS     |
# | Chords 1                          | rhythm-10-0-0     | 10-0-0     | PASS     |
# +-----------------------------------+-------------------+------------+----------+
#
# Pass: 100.0% (120), Fail: 0.0% (0), Total: 120

# %%
#plot the training and validation accuracy and loss at each epoch
plt.subplot(1, 2, 1)
loss = model_fit.history['loss']
val_loss = model_fit.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'royalblue', label='Training loss')
plt.plot(epochs, val_loss, 'coral', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
acc = model_fit.history['accuracy']
val_acc = model_fit.history['val_accuracy']
plt.plot(epochs, acc, 'royalblue', label='Training acc')
plt.plot(epochs, val_acc, 'coral', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.rcParams['figure.figsize'] = [12, 5]
plt.tight_layout()
plt.savefig("test.pdf", format="pdf")
plt.show()

# %%
#model.save('eq2.h5')
