# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import normalize, to_categorical
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from prettytable import PrettyTable

# %%
rootPath = './spectrograms2/All2/'
imgPath = 'test/'
testImgPath = rootPath + imgPath + os.listdir(rootPath + imgPath)[0]
res = [cv2.imread(testImgPath).shape[0], cv2.imread(testImgPath).shape[1]]

print('Current Resolution: \t' + str(res))

#res = [int(res[0]/2), int(res[1]/2)]
#print('New Resolution: \t' + str(res))

#res = [int(res[0]/1.5), int(res[1]/1.5)]
#print('New Resolution: \t' + str(res))

res = [int(res[0]/4), int(res[1]/4)]
print('New Resolution: \t' + str(res))
# Out:
# Current Resolution: 	[540, 1080]
# New Resolution: 	[135, 270]

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory(
    rootPath + 'train/',
    target_size = (res[0], res[1]),
    batch_size = 20,
    class_mode = 'binary'
)

validation_dataset = validation.flow_from_directory(
    rootPath + 'validate/',
    target_size = (res[0], res[1]),
    batch_size = 20,
    class_mode = 'binary'
)
# Out:
# Found 400 images belonging to 2 classes.
# Found 101 images belonging to 2 classes.

# %%
#print(train_dataset.class_indices)
#print(validation_dataset.class_indices)

# %% [markdown]
# # train generator (rotate images)
#
# train_datagen = ImageDataGenerator(rotation_range=45,
#     width_shift_range=0.2,
#     zoom_range = 0.2,
#     horizontal_flip = True)
# train_datagen.fit(train_dataset)
#
# train_generator = train_datagen.flow(
#     train_dataset,
#     batch_size = 32)

# %%
# old model
activation = 'relu'
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation=activation, input_shape=(res[0], res[1], 3)),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(32,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    #
    tf.keras.layers.Conv2D(64,(3,3), activation=activation),
    tf.keras.layers.MaxPool2D(2,2),
    ##
    tf.keras.layers.Flatten(),
    ##
    tf.keras.layers.Dense(512, activation=activation),
    ##
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

# %% [markdown]
# activation = 'sigmoid'
# model = Sequential()
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', input_shape = (res[0], res[1], 3)))
# model.add(BatchNormalization())
#
# model.add(Conv2D(32, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
#
# model.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
#
# model.add(Flatten())
# model.add(Dense(128, activation = activation, kernel_initializer = 'he_uniform'))
# model.add(Dense(1, activation = 'softmax'))
#
# model.compile(optimizer = 'rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
# print(model.summary())

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(lr=0.001),
    metrics=['accuracy']
)

# %%
model_fit = model.fit(
    train_dataset,
    steps_per_epoch=20,
    epochs=100,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 18s 850ms/step - loss: 1.0140 - accuracy: 0.4773 - val_loss: 0.6911 - val_accuracy: 0.6337
# Epoch 2/100
# 20/20 [==============================] - 18s 874ms/step - loss: 0.6921 - accuracy: 0.5646 - val_loss: 0.6748 - val_accuracy: 0.6139
# Epoch 3/100
# 20/20 [==============================] - 22s 1s/step - loss: 0.6865 - accuracy: 0.5644 - val_loss: 0.6319 - val_accuracy: 0.7228
# Epoch 4/100
# 20/20 [==============================] - 21s 1s/step - loss: 0.6492 - accuracy: 0.6574 - val_loss: 0.6015 - val_accuracy: 0.6931
# Epoch 5/100
# 20/20 [==============================] - 21s 1s/step - loss: 0.6120 - accuracy: 0.6988 - val_loss: 0.5222 - val_accuracy: 0.7228
# Epoch 6/100
# 20/20 [==============================] - 22s 1s/step - loss: 0.5504 - accuracy: 0.7261 - val_loss: 0.4549 - val_accuracy: 0.8416
# Epoch 7/100
# 20/20 [==============================] - 21s 1s/step - loss: 0.5170 - accuracy: 0.7752 - val_loss: 0.4586 - val_accuracy: 0.8020
# Epoch 8/100
# 20/20 [==============================] - 21s 1s/step - loss: 0.4523 - accuracy: 0.7869 - val_loss: 0.4918 - val_accuracy: 0.7525
# Epoch 9/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.4257 - accuracy: 0.7919 - val_loss: 0.4003 - val_accuracy: 0.8317
# Epoch 10/100
# 20/20 [==============================] - 22s 1s/step - loss: 0.3268 - accuracy: 0.8634 - val_loss: 0.3214 - val_accuracy: 0.8911
# Epoch 11/100
# 20/20 [==============================] - 27s 1s/step - loss: 0.3016 - accuracy: 0.8708 - val_loss: 0.3723 - val_accuracy: 0.8317
# Epoch 12/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.3041 - accuracy: 0.8688 - val_loss: 0.3635 - val_accuracy: 0.8515
# Epoch 13/100
# 20/20 [==============================] - 24s 1s/step - loss: 0.2971 - accuracy: 0.8997 - val_loss: 0.2308 - val_accuracy: 0.9109
# Epoch 14/100
# 20/20 [==============================] - 31s 2s/step - loss: 0.2498 - accuracy: 0.9085 - val_loss: 0.2593 - val_accuracy: 0.9010
# Epoch 15/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.2075 - accuracy: 0.9273 - val_loss: 0.2319 - val_accuracy: 0.9010
# Epoch 16/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.2371 - accuracy: 0.8982 - val_loss: 0.2060 - val_accuracy: 0.9109
# Epoch 17/100
# 20/20 [==============================] - 31s 1s/step - loss: 0.1109 - accuracy: 0.9561 - val_loss: 0.4745 - val_accuracy: 0.8119
# Epoch 18/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.1760 - accuracy: 0.9458 - val_loss: 0.2911 - val_accuracy: 0.8812
# Epoch 19/100
# 20/20 [==============================] - 30s 1s/step - loss: 0.1178 - accuracy: 0.9590 - val_loss: 0.2633 - val_accuracy: 0.8812
# Epoch 20/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.1135 - accuracy: 0.9705 - val_loss: 0.3051 - val_accuracy: 0.8812
# Epoch 21/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.0753 - accuracy: 0.9752 - val_loss: 0.1858 - val_accuracy: 0.9010
# Epoch 22/100
# 20/20 [==============================] - 27s 1s/step - loss: 0.0678 - accuracy: 0.9752 - val_loss: 0.1644 - val_accuracy: 0.9208
# Epoch 23/100
# 20/20 [==============================] - 34s 2s/step - loss: 0.0386 - accuracy: 0.9923 - val_loss: 0.1456 - val_accuracy: 0.9307
# Epoch 24/100
# 20/20 [==============================] - 28s 1s/step - loss: 0.0768 - accuracy: 0.9864 - val_loss: 0.1226 - val_accuracy: 0.9604
# Epoch 25/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.0195 - accuracy: 0.9985 - val_loss: 0.7613 - val_accuracy: 0.7723
# Epoch 26/100
# 20/20 [==============================] - 30s 1s/step - loss: 0.1125 - accuracy: 0.9629 - val_loss: 0.0944 - val_accuracy: 0.9802
# Epoch 27/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9802
# Epoch 28/100
# 20/20 [==============================] - 28s 1s/step - loss: 0.0572 - accuracy: 0.9849 - val_loss: 0.1816 - val_accuracy: 0.9208
# Epoch 29/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.0275 - accuracy: 0.9964 - val_loss: 0.3073 - val_accuracy: 0.8713
# Epoch 30/100
# 20/20 [==============================] - 28s 1s/step - loss: 0.0382 - accuracy: 0.9863 - val_loss: 0.1133 - val_accuracy: 0.9604
# Epoch 31/100
# 20/20 [==============================] - 33s 2s/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.1742 - val_accuracy: 0.9109
# Epoch 32/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4355 - val_accuracy: 0.8713
# Epoch 33/100
# 20/20 [==============================] - 31s 2s/step - loss: 0.0871 - accuracy: 0.9670 - val_loss: 0.1945 - val_accuracy: 0.8911
# Epoch 34/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.0118 - accuracy: 0.9995 - val_loss: 0.0951 - val_accuracy: 0.9703
# Epoch 35/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9406
# Epoch 36/100
# 20/20 [==============================] - 29s 1s/step - loss: 2.4370e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9505
# Epoch 37/100
# 20/20 [==============================] - 32s 2s/step - loss: 5.6002e-05 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9703
# Epoch 38/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.0673 - accuracy: 0.9858 - val_loss: 0.1579 - val_accuracy: 0.9406
# Epoch 39/100
# 20/20 [==============================] - 30s 1s/step - loss: 0.0282 - accuracy: 0.9905 - val_loss: 0.1779 - val_accuracy: 0.9208
# Epoch 40/100
# 20/20 [==============================] - 31s 2s/step - loss: 0.0101 - accuracy: 0.9922 - val_loss: 0.1478 - val_accuracy: 0.9307
# Epoch 41/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.0034 - accuracy: 0.9983 - val_loss: 0.1168 - val_accuracy: 0.9505
# Epoch 42/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.0169 - accuracy: 0.9961 - val_loss: 0.4629 - val_accuracy: 0.8812
# Epoch 43/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.0617 - accuracy: 0.9783 - val_loss: 0.1753 - val_accuracy: 0.9406
# Epoch 44/100
# 20/20 [==============================] - 31s 2s/step - loss: 5.1113e-04 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.9505
# Epoch 45/100
# 20/20 [==============================] - 28s 1s/step - loss: 2.3747e-04 - accuracy: 1.0000 - val_loss: 0.1798 - val_accuracy: 0.9505
# Epoch 46/100
# 20/20 [==============================] - 32s 2s/step - loss: 1.2648e-04 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.9505
# Epoch 47/100
# 20/20 [==============================] - 27s 1s/step - loss: 2.6831e-05 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9406
# Epoch 48/100
# 20/20 [==============================] - 33s 2s/step - loss: 0.1223 - accuracy: 0.9765 - val_loss: 0.1818 - val_accuracy: 0.9307
# Epoch 49/100
# 20/20 [==============================] - 27s 1s/step - loss: 7.9213e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9604
# Epoch 50/100
# 20/20 [==============================] - 32s 2s/step - loss: 7.8180e-05 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9604
# Epoch 51/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.0304 - accuracy: 0.9967 - val_loss: 0.5056 - val_accuracy: 0.9010
# Epoch 52/100
# 20/20 [==============================] - 32s 2s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9406
# Epoch 53/100
# 20/20 [==============================] - 27s 1s/step - loss: 6.8468e-04 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9406
# Epoch 54/100
# 20/20 [==============================] - 33s 2s/step - loss: 2.8547e-04 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9604
# Epoch 55/100
# 20/20 [==============================] - 28s 1s/step - loss: 1.0310e-04 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9505
# Epoch 56/100
# 20/20 [==============================] - 31s 2s/step - loss: 2.0871e-05 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9406
# Epoch 57/100
# 20/20 [==============================] - 29s 1s/step - loss: 8.9765e-06 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9406
# Epoch 58/100
# 20/20 [==============================] - 30s 2s/step - loss: 3.1781e-06 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9406
# Epoch 59/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 3.0609 - val_accuracy: 0.7921
# Epoch 60/100
# 20/20 [==============================] - 29s 1s/step - loss: 0.3690 - accuracy: 0.9392 - val_loss: 0.1654 - val_accuracy: 0.9406
# Epoch 61/100
# 20/20 [==============================] - 29s 1s/step - loss: 2.2547e-04 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9406
# Epoch 62/100
# 20/20 [==============================] - 29s 1s/step - loss: 1.0194e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9406
# Epoch 63/100
# 20/20 [==============================] - 23s 1s/step - loss: 6.3214e-05 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9406
# Epoch 64/100
# 20/20 [==============================] - 18s 896ms/step - loss: 1.7652e-05 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9505
# Epoch 65/100
# 20/20 [==============================] - 21s 1s/step - loss: 6.3516e-06 - accuracy: 1.0000 - val_loss: 0.2554 - val_accuracy: 0.9406
# Epoch 66/100
# 20/20 [==============================] - 17s 822ms/step - loss: 0.0719 - accuracy: 0.9807 - val_loss: 0.1958 - val_accuracy: 0.9307
# Epoch 67/100
# 20/20 [==============================] - 21s 1s/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.4591 - val_accuracy: 0.8911
# Epoch 68/100
# 20/20 [==============================] - 17s 824ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2592 - val_accuracy: 0.9406
# Epoch 69/100
# 20/20 [==============================] - 21s 1s/step - loss: 4.6847e-05 - accuracy: 1.0000 - val_loss: 0.2731 - val_accuracy: 0.9406
# Epoch 70/100
# 20/20 [==============================] - 17s 827ms/step - loss: 1.4799e-05 - accuracy: 1.0000 - val_loss: 0.2705 - val_accuracy: 0.9307
# Epoch 71/100
# 20/20 [==============================] - 21s 1s/step - loss: 6.0791e-06 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9307
# Epoch 72/100
# 20/20 [==============================] - 17s 812ms/step - loss: 3.3801e-06 - accuracy: 1.0000 - val_loss: 0.2874 - val_accuracy: 0.9406
# Epoch 73/100
# 20/20 [==============================] - 20s 1s/step - loss: 3.0538e-06 - accuracy: 1.0000 - val_loss: 0.3328 - val_accuracy: 0.9406
# Epoch 74/100
# 20/20 [==============================] - 17s 840ms/step - loss: 7.4241e-07 - accuracy: 1.0000 - val_loss: 0.3024 - val_accuracy: 0.9406
# Epoch 75/100
# 20/20 [==============================] - 21s 1s/step - loss: 1.8586e-07 - accuracy: 1.0000 - val_loss: 0.2740 - val_accuracy: 0.9505
# Epoch 76/100
# 20/20 [==============================] - 18s 884ms/step - loss: 0.3436 - accuracy: 0.9709 - val_loss: 0.1825 - val_accuracy: 0.9307
# Epoch 77/100
# 20/20 [==============================] - 21s 1s/step - loss: 1.6169e-04 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9406
# Epoch 78/100
# 20/20 [==============================] - 18s 897ms/step - loss: 7.1094e-05 - accuracy: 1.0000 - val_loss: 0.1790 - val_accuracy: 0.9406
# Epoch 79/100
# 20/20 [==============================] - 20s 1s/step - loss: 2.5408e-05 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9505
# Epoch 80/100
# 20/20 [==============================] - 19s 917ms/step - loss: 0.0102 - accuracy: 0.9983 - val_loss: 0.4443 - val_accuracy: 0.8911
# Epoch 81/100
# 20/20 [==============================] - 20s 1s/step - loss: 0.0133 - accuracy: 0.9971 - val_loss: 0.2985 - val_accuracy: 0.9307
# Epoch 82/100
# 20/20 [==============================] - 19s 936ms/step - loss: 0.0062 - accuracy: 0.9971 - val_loss: 0.2817 - val_accuracy: 0.9406
# Epoch 83/100
# 20/20 [==============================] - 20s 993ms/step - loss: 4.8875e-05 - accuracy: 1.0000 - val_loss: 0.2546 - val_accuracy: 0.9505
# Epoch 84/100
# 20/20 [==============================] - 19s 956ms/step - loss: 2.1424e-05 - accuracy: 1.0000 - val_loss: 0.2512 - val_accuracy: 0.9505
# Epoch 85/100
# 20/20 [==============================] - 18s 930ms/step - loss: 1.2024e-05 - accuracy: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.9604
# Epoch 86/100
# 20/20 [==============================] - 21s 1s/step - loss: 6.6277e-06 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9604
# Epoch 87/100
# 20/20 [==============================] - 18s 900ms/step - loss: 2.6165e-06 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9406
# Epoch 88/100
# 20/20 [==============================] - 21s 1s/step - loss: 7.1529e-07 - accuracy: 1.0000 - val_loss: 0.2762 - val_accuracy: 0.9406
# Epoch 89/100
# 20/20 [==============================] - 17s 857ms/step - loss: 2.2217e-07 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.9406
# Epoch 90/100
# 20/20 [==============================] - 21s 1s/step - loss: 1.0780e-07 - accuracy: 1.0000 - val_loss: 0.3536 - val_accuracy: 0.9505
# Epoch 91/100
# 20/20 [==============================] - 17s 845ms/step - loss: 0.1278 - accuracy: 0.9882 - val_loss: 0.2259 - val_accuracy: 0.9307
# Epoch 92/100
# 20/20 [==============================] - 21s 1s/step - loss: 2.9060e-05 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9406
# Epoch 93/100
# 20/20 [==============================] - 17s 815ms/step - loss: 7.1179e-06 - accuracy: 1.0000 - val_loss: 0.2414 - val_accuracy: 0.9406
# Epoch 94/100
# 20/20 [==============================] - 21s 1s/step - loss: 3.4282e-06 - accuracy: 1.0000 - val_loss: 0.2530 - val_accuracy: 0.9406
# Epoch 95/100
# 20/20 [==============================] - 17s 821ms/step - loss: 3.4033e-06 - accuracy: 1.0000 - val_loss: 0.2598 - val_accuracy: 0.9505
# Epoch 96/100
# 20/20 [==============================] - 21s 1s/step - loss: 1.5573e-06 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.9505
# Epoch 97/100
# 20/20 [==============================] - 17s 805ms/step - loss: 5.8199e-07 - accuracy: 1.0000 - val_loss: 0.2991 - val_accuracy: 0.9505
# Epoch 98/100
# 20/20 [==============================] - 21s 1s/step - loss: 2.6754e-07 - accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9505
# Epoch 99/100
# 20/20 [==============================] - 17s 842ms/step - loss: 1.1835e-07 - accuracy: 1.0000 - val_loss: 0.3514 - val_accuracy: 0.9505
# Epoch 100/100
# 20/20 [==============================] - 20s 1s/step - loss: 4.0988e-08 - accuracy: 1.0000 - val_loss: 0.3934 - val_accuracy: 0.9406

# %%
def resultStore(file, pred, results):
    pred = pred.lower()
    if pred in file:
        results[0] = 'PASS'
        results[1] = results[1] + 1
    else:
        results[0] = 'FAIL'
        results[2] = results[2] + 1
    return results

def resultStats(results):
    total = results[1] + results[2]
    p = round(results[1]*100/total, 2)
    f = round(results[2]*100/total, 2)
    return 'Pass: ' + str(p) + '% (' + str(results[1]) + '), Fail: ' + str(f) + '% (' + str(results[2]) + '), Total: ' + str(total)

# %%
validation_dataset.class_indices
classes = {v: k for k, v in validation_dataset.class_indices.items()}
print(classes)
# Out:
# {0: 'lead', 1: 'rhythm'}

# %% [markdown]
# testPath = rootPath + 'test/'
# results = ["", 0, 0]
#
# table = PrettyTable()
# table.field_names = ["1", "File", "2", "Class", "3", "Prediction", "4", "Result", " "]
#
# for i in os.listdir(testPath):
#     img = image.load_img(
#         testPath + '//' + i,
#         target_size = (res[0], res[1])
#     )
#
#     X = image.img_to_array(img)
#     X = np.expand_dims(X, axis=0)
#     images = np.vstack([X])
#     prediction = int(model.predict(images))
#
#     results = resultStore(i, classes[prediction][3:-4], results)
#     splt = i.split('_session_')
#     clss = splt[0]
#     fname = splt[1].replace('_', ' ')
#     table.add_row(["", fname[:-4], "", clss, "", classes[prediction][3:-4], "", results[0], ""])
#
# table.align = 'l'
# print(table)
#
# print('\n' + resultStats(results))

# %%
def get_precision(prec, result):
    if result == "PASS":
        prec[0] = prec[0] + 1
        prec[1] = prec[1] + 1
    else:
        prec[1] = prec[1] + 1
    return prec

def get_recall(rec, result, clss):
    if clss == 0:
        if result == "PASS":
            rec[0] = rec[0] + 1
            rec[1] = rec[1] + 1
        else:
            rec[3] = rec[3] + 1
    else:
        if result == "PASS":
            rec[2] = rec[2] + 1
            rec[3] = rec[3] + 1
        else:
            rec[1] = rec[1] + 1
    return rec

def get_fscore(prec, rec):
    return 2 * ((prec * rec) / (prec + rec))

def get_metrics(precision1, precision2, recall, classes):
    precision = [round((precision1[0]/precision1[1]), 2)*100, round((precision2[0]/precision2[1]), 2)*100]
    recall = [round((recall[0]/recall[1]), 2)*100, round((recall[2]/recall[3]), 2)*100]
    fscore = [round(get_fscore(precision[0], recall[0])/100,2), round(get_fscore(precision[1], recall[1])/100,2)]

    metrics_table = PrettyTable()
    metrics_table.field_names = ["Class", "Precision", "Recall", "F-Score"]
    for i in classes:
        metrics_table.add_row([classes[i], precision[i], recall[i], fscore[i]])
    return metrics_table

# %%
recall = [0,0,0,0]
precision1 = [0,0]
precision2 = [0,0]
fscore = [0,0]

testPath = rootPath + 'test/'
results = ["", 0, 0]

table = PrettyTable()
table.field_names = ["File", "Class", "Prediction", "Result"]

for i in os.listdir(testPath):
    img = image.load_img(
        testPath + '//' + i,
        target_size = (res[0], res[1])
    )

    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    prediction = int(model.predict(images))
    
    results = resultStore(i, classes[prediction], results)
    splt = i.split('_session_')
    clss = splt[0]
    fname = splt[1].replace('_', ' ')
    table.add_row([fname[:-4] + "    ", clss + "    ", classes[prediction], results[0] + "    "])

    if(prediction==0):
        precision1 = get_precision(precision1, results[0])
        recall = get_recall(recall, results[0], prediction)
    else:
        precision2 = get_precision(precision2, results[0])
        recall = get_recall(recall, results[0], prediction)

table.align = 'l'
print(table)

print('\n' + resultStats(results))

print(get_metrics(precision1, precision2, recall, classes))
# Out:
# +-----------------------------------+-------------------+------------+----------+
# | File                              | Class             | Prediction | Result   |
# +-----------------------------------+-------------------+------------+----------+
# | Audio 41                          | lead-0-0-10       | lead       | PASS     |
# | Audio 42                          | lead-0-0-10       | lead       | PASS     |
# | Audio 43                          | lead-0-0-10       | lead       | PASS     |
# | Audio 44                          | lead-0-0-10       | lead       | PASS     |
# | Audio 45                          | lead-0-0-10       | lead       | PASS     |
# | Audio 46                          | lead-0-0-10       | lead       | PASS     |
# | Audio 47                          | lead-0-0-10       | rhythm     | FAIL     |
# | Audio 48                          | lead-0-0-10       | lead       | PASS     |
# | Audio 49                          | lead-0-0-10       | lead       | PASS     |
# | Audio 50                          | lead-0-0-10       | lead       | PASS     |
# | Audio 41                          | lead-0-10-0       | rhythm     | FAIL     |
# | Audio 42                          | lead-0-10-0       | lead       | PASS     |
# | Audio 43                          | lead-0-10-0       | lead       | PASS     |
# | Audio 44                          | lead-0-10-0       | lead       | PASS     |
# | Audio 45                          | lead-0-10-0       | lead       | PASS     |
# | Audio 46                          | lead-0-10-0       | lead       | PASS     |
# | Audio 47                          | lead-0-10-0       | lead       | PASS     |
# | Audio 48                          | lead-0-10-0       | lead       | PASS     |
# | Audio 49                          | lead-0-10-0       | lead       | PASS     |
# | Audio 50                          | lead-0-10-0       | lead       | PASS     |
# | Audio 41                          | lead-10-0-0       | rhythm     | FAIL     |
# | Audio 42                          | lead-10-0-0       | lead       | PASS     |
# | Audio 43                          | lead-10-0-0       | lead       | PASS     |
# | Audio 44                          | lead-10-0-0       | lead       | PASS     |
# | Audio 45                          | lead-10-0-0       | lead       | PASS     |
# | Audio 46                          | lead-10-0-0       | lead       | PASS     |
# | Audio 47                          | lead-10-0-0       | lead       | PASS     |
# | Audio 48                          | lead-10-0-0       | lead       | PASS     |
# | Audio 49                          | lead-10-0-0       | lead       | PASS     |
# | Audio 50                          | lead-10-0-0       | lead       | PASS     |
# | Audio 51                          | lead              | lead       | PASS     |
# | Audio 52                          | lead              | lead       | PASS     |
# | Audio 53                          | lead              | lead       | PASS     |
# | Audio 54                          | lead              | lead       | PASS     |
# | Audio 55                          | lead              | lead       | PASS     |
# | Audio 56                          | lead              | lead       | PASS     |
# | Audio 57                          | lead              | lead       | PASS     |
# | Audio 58                          | lead              | lead       | PASS     |
# | Audio 59                          | lead              | lead       | PASS     |
# | Audio 60                          | lead              | lead       | PASS     |
# | Soundcloud 10                     | lead              | lead       | PASS     |
# | The Call Of Ktulu 2               | lead              | rhythm     | FAIL     |
# | The Number Of The Beast 2         | lead              | rhythm     | FAIL     |
# | The Pale King 2                   | lead              | lead       | PASS     |
# | The Call Of Ktulu                 | lead              | lead       | PASS     |
# | The Number Of The Beast           | lead              | lead       | PASS     |
# | The Pale King                     | lead              | lead       | PASS     |
# | You Shook Me All Night Long 2     | lead              | lead       | PASS     |
# | You Shook Me All Night Long 3     | lead              | lead       | PASS     |
# | You Shook Me All Night Long       | lead              | lead       | PASS     |
# | Audio 41                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 42                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 43                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 44                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 45                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 46                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 47                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 48                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 49                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 50                          | rhythm-0-0-10     | rhythm     | PASS     |
# | Audio 41                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 42                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 43                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 44                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 45                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 46                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 47                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 48                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 49                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 50                          | rhythm-0-10-0     | rhythm     | PASS     |
# | Audio 41                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 42                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 43                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 44                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 45                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 46                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 47                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 48                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 49                          | rhythm-10-0-0     | lead       | FAIL     |
# | Audio 50                          | rhythm-10-0-0     | rhythm     | PASS     |
# | Audio 51                          | rhythm            | rhythm     | PASS     |
# | Audio 52                          | rhythm            | rhythm     | PASS     |
# | Audio 53                          | rhythm            | rhythm     | PASS     |
# | Audio 54                          | rhythm            | rhythm     | PASS     |
# | Audio 55                          | rhythm            | rhythm     | PASS     |
# | Audio 56                          | rhythm            | rhythm     | PASS     |
# | Audio 57                          | rhythm            | rhythm     | PASS     |
# | Audio 58                          | rhythm            | rhythm     | PASS     |
# | Audio 59                          | rhythm            | rhythm     | PASS     |
# | Audio 60                          | rhythm            | rhythm     | PASS     |
# | Soundcloud 10                     | rhythm            | rhythm     | PASS     |
# | The Call Of Ktulu 2               | rhythm            | rhythm     | PASS     |
# | The Number Of The Beast 2         | rhythm            | lead       | FAIL     |
# | The Pale King 2                   | rhythm            | rhythm     | PASS     |
# | The Call Of Ktulu                 | rhythm            | rhythm     | PASS     |
# | The Number Of The Beast           | rhythm            | lead       | FAIL     |
# | The Pale King                     | rhythm            | rhythm     | PASS     |
# | You Shook Me All Night Long 2     | rhythm            | rhythm     | PASS     |
# | You Shook Me All Night Long 3     | rhythm            | rhythm     | PASS     |
# | You Shook Me All Night Long       | rhythm            | rhythm     | PASS     |
# +-----------------------------------+-------------------+------------+----------+
#
# Pass: 92.0% (92), Fail: 8.0% (8), Total: 100
# +--------+-----------+--------+---------+
# | Class  | Precision | Recall | F-Score |
# +--------+-----------+--------+---------+
# |  lead  |    94.0   |  90.0  |  91.96  |
# | rhythm |    90.0   |  94.0  |  91.96  |
# +--------+-----------+--------+---------+

# %%
#plot the training and validation accuracy and loss at each epoch
plt.subplot(1, 2, 1)
loss = model_fit.history['loss']
val_loss = model_fit.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'royalblue', label='Training loss')
plt.plot(epochs, val_loss, 'coral', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
acc = model_fit.history['accuracy']
val_acc = model_fit.history['val_accuracy']
plt.plot(epochs, acc, 'royalblue', label='Training acc')
plt.plot(epochs, val_acc, 'coral', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.rcParams['figure.figsize'] = [12, 5]
plt.tight_layout()
plt.savefig("test.pdf", format="pdf")
plt.show()

# %%
model.save('lead-rhythm-92.5p.h5')
